# %%
import sys
import matplotlib
import matplotlib.pyplot as plt
from scipy import stats

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
slope, intercept, r, p, std_err = stats.linregress(x, y)
def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %% [markdown]
# Machine learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import numpy as np
import pandas as pd

# %%
x=np.array([1,2,3,4,8,9,10,11])
y=np.array([4,5,6,7,8,9,10,11])
x=x.reshape(-1,1)
x
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=22)
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([4.82926829, 6.09756098])

# %%
X_test
# Out:
# array([[2],
#        [4]])

# %%
x=np.array([1,1234433451,2341235,123413,235134531,3244135,345,134513451345,542153451])

# %%
np.sum(x)
# Out:
# 136530881907

# %%
np.mean(x)
# Out:
# 15170097989.666666

# %%
np.median(x)
# Out:
# 3244135.0

# %%
np.linspace(1,10,11)
# Out:
# array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ])

# %%
np.random.choice([0,1])
# Out:
# 0

# %%
np.random.choice([0,1,2,3],size=5)
# Out:
# array([1, 0, 3, 1, 3])

# %%
x=[1,12,8,1,5]
y=[1,324,9,6,1]
np.add(x,y)
# Out:
# array([  2, 336,  17,   7,   6])

# %%
np.subtract(x,y)
# Out:
# array([   0, -312,   -1,   -5,    4])

# %%
np.multiply(x,y)
# Out:
# array([   1, 3888,   72,    6,    5])

# %%
np.sum(x)
# Out:
# 27

# %%
8.8/27
# Out:
# 0.32592592592592595

# %%
x=[1,2,3,4,5,6,7]
y=[1,8,3,100,1,8,3]
z=[80,70,60,50,60,70,80]
plt.plot(x,y,x,z)
plt.title('x=y graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
x=np.arange(0,10,2)
y=x**2
plt.plot(x,y,marker='.')

# %%
plt.bar(x,y, color='black', width=0.8)
plt.title('bar graph')
plt.show()

# %%
x=[23,4,50,6]
y=['a','b','c','d']
plt.pie(x,labels=y)
plt.show()

# %%
x=[4,1,6,5,4]
y=['SciFi: 4(20%)','Drama: 1(5%)','Romance: 6(30%)','Action: 5(25%)','Comedy: 4(20%)']
plt.pie(x,labels=y,autopct='%1.1f%%')
plt.show()

# %%
marks_list=[1,2,12,23,32,39,40,56,89,100,34,56,22,53,56,66,67]
grade=[0,10,20,30,40,50,60,70,90,100]
plt.hist(marks_list,grade)
plt.show()
